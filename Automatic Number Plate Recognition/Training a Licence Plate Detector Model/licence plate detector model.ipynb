# %% [markdown]
# # License Plate Detector Model

# %% [markdown]
# ## Installation requirements

# %%
# !pip install datasets ultralytics opencv-python numpy pandas matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Model Downloading

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lLsUyTYq1pdYuX6oscWG")
project = rf.workspace("augmented-startups").project("vehicle-registration-plates-trudk")
version = project.version(2)
dataset = version.download("yolo26")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 51.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Vehicle-Registration-Plates-2 in yolo26:: 100%|██████████| 42362/42362 [00:06<00:00, 6905.43it/s]

# %% [markdown]
# ## Model Training

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(data="data.yaml", epochs=10, imgsz=416, batch=16)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# ## Model Evaluation

# %%
metrics = model.val()
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 93 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1281.0±517.9 MB/s, size: 27.6 KB)
# val: Scanning /content/dataset/valid/labels.cache... 1765 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1765/1765 673.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 111/111 4.5it/s 24.5s
#                    all       1765       1840      0.989      0.958      0.983      0.707
# Speed: 0.6ms preprocess, 10.0ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /content/runs/detect/val

# %% [markdown]
# ## Model Saving

# %%
model.save('license_plate_detector_model.pt')
print("Model saved as license_plate_detector_model.pt")
# Out:
# Model saved as license_plate_detector_model.pt

# %% [markdown]
# ---
