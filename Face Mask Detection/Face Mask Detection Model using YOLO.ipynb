# %% [markdown]
# # Face Mask Detection Model using YOLO

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.4 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load a pretrained YOLO26n model

# %%
model = YOLO("yolo26m.pt")

# %% [markdown]
# ## Train the model on a custom dataset for face mask detection

# %%
results = model.train(data="config.yaml", epochs=50, imgsz=640, device=0)
# Out:
# Attempting to verify training path: /content/drive/MyDrive/FaceMaskYOLOModelTraining/dataset/train/images
# Attempting to verify validation path: /content/drive/MyDrive/FaceMaskYOLOModelTraining/dataset/val/images
# Existing config.yaml loaded. Overwriting paths and class info.
#
# Updated config.yaml saved to /content/drive/MyDrive/FaceMaskYOLOModelTraining/config.yaml with:
#   path: /content/drive/MyDrive/FaceMaskYOLOModelTraining/dataset
#   train: train/images
#   val: val/images
#   nc: 2
#   names: ['mask', 'no_mask']
#
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# ## Evaluate the model on a validation set

# %%
metrics = model.val()
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26m summary (fused): 132 layers, 20,350,994 parameters, 0 gradients, 67.9 GFLOPs
# val: Fast image access ✅ (ping: 5.3±11.2 ms, read: 53.6±59.1 MB/s, size: 381.1 KB)
# val: Scanning /content/drive/MyDrive/FaceMaskYOLOModelTraining/dataset/val/labels.cache... 171 images, 0 backgrounds, 53 corrupt: 100% ━━━━━━━━━━━━ 171/171 39.8Mit/s 0.0s
# val: /content/drive/MyDrive/FaceMaskYOLOModelTraining/dataset/val/images/maksssksksss108.png: ignoring corrupt image/label: Label class 2 exceeds dataset class count 2. Possible class labels are 0-1
# val: /content/drive/MyDrive/FaceMaskYOLOModelTraining/dataset/val/images/maksssksksss125.png: ignoring corrupt image/label: Label class 2 exceeds dataset class count 2. Possible class labels are 0-1
# ...

# %% [markdown]
# ## Export the trained model for usage in other applications

# %%
model.export(format="onnx")
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
#
# PyTorch: starting from '/content/runs/detect/train3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (42.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 12 packages in 216ms
# Prepared 4 packages in 3.80s
# Installed 4 packages in 494ms
#  + colorama==0.4.6
#  + onnx==1.20.1
#  + onnxruntime-gpu==1.24.2
#  + onnxslim==0.1.86
#
# requirements: AutoUpdate success ✅ 5.2s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.20.1 opset 22...
# ...

# %% [markdown]
# ---
